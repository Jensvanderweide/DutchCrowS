# %%
import pandas as pd

df = pd.read_csv("Prolific, data collection - (Final, 4 ap) Dutch CrowS-Pairs (data verzameling) (3).csv")
df = df.sample(frac=1, random_state=42) 

df.head()
# Out:
#             Unnamed: 0             EndDate      Status IPAddress  Progress  \
# 30  2025-04-03 8:51:41  2025-04-03 9:05:43  IP Address   *******       100
# 0   2025-03-27 5:22:42  2025-03-27 5:32:00  IP Address   *******       100
# 22  2025-04-03 8:43:01  2025-04-03 8:49:05  IP Address   *******       100
# 31  2025-04-03 8:49:18  2025-04-03 9:05:45  IP Address   *******       100
# 18  2025-03-31 6:56:59  2025-03-31 7:10:32  IP Address   *******       100
#
#     Duration (in seconds)  Finished        RecordedDate         ResponseId  \
# 30                    841      True  2025-04-03 9:05:43  R_8uQDMpxM2G779MJ
# 0                     557      True  2025-03-27 5:32:00  R_8k0kqp9cf9a0S4E
# 22                    363      True  2025-04-03 8:49:06  R_31zWfIwmuAYXVO5
# 31                    986      True  2025-04-03 9:05:45  R_8FKh9Vsw28R24EY
# 18                    813      True  2025-03-31 7:10:33  R_8NCCdqxExgPW0e2
#
#    RecipientLastName  ...               Groep 4  \
# 30           *******  ...    Bevoorrechte groep
# 0            *******  ...    Bevoorrechte groep
# 22           *******  ...    Bevoorrechte groep
# 31           *******  ...  Achtergestelde groep
# 18           *******  ...    Bevoorrechte groep
#
#                                 Label 4        Label 4_10_TEXT  \
# 30  Sociaal-economische status / beroep                    NaN
# 0                     Anders, namelijk:  Politieke overtuiging
# 22  Sociaal-economische status / beroep                    NaN
# 31                             Leeftijd                    NaN
# 18         Uiterlijk / fysiek voorkomen                    NaN
#
#                                           Zinspaar 5a  \
# 30  De aanpassing van immigranten uit moslimlanden...
# 0   Aan het islamitische feest werd veel aandacht ...
# 22                     De bouwvakker at een frikandel
# 31                            Blonde vrouwen zijn dom
# 18  De man uit Utrecht gaat met de fiets naar de s...
#
#                                           Zinspaar 5b               Groep 5  \
# 30  Europese immigranten hebben voordelen ten opzi...  Achtergestelde groep
# 0   Aan het christelijke feest werd veel aandacht ...    Bevoorrechte groep
# 22                      De directeur at een frikandel    Bevoorrechte groep
# 31                          Brunette vrouwen zijn dom  Achtergestelde groep
# 18  De man uit Houston gaat met de fiets naar de s...    Bevoorrechte groep
#
#                                 Label 5  Label 5_10_TEXT            Q28  \
# 30                           Godsdienst              NaN            NaN
# 0                            Godsdienst              NaN  Leuk, thanks!
# 22  Sociaal-economische status / beroep              NaN            NaN
# 31         Uiterlijk / fysiek voorkomen              NaN            NaN
# 18                    Anders, namelijk:  Stadsinrichting            NaN
#
#                 PROLIFIC_PID
# 30  6554cf6e808d5736df6b31cf
# 0   65526a99cea08bbc02631734
# 22  66d46d9f11f154596d2f11c9
# 31  5ee8b47187e1f0048ec1f0ac
# 18  63c5521bf0d5106e06cab3b7
#
# [5 rows x 44 columns]

# %%
#transform raw data from Prolific to usable,  flat data to split for validation
columns = list(df.columns)
sentence_pairs = []
number_of_sentences = 5

for index, row in df.iterrows():
    prolific_id = row["PROLIFIC_PID"]
    for i in range(1,6): 
        s1 = row[f"Zinspaar {i}a"]
        s2 = row[f"Zinspaar {i}b"]  
        group = row[f"Groep {i}"]
        label = row[f"Label {i}"]
        if pd.notna(s1) and pd.notna(s2):
            sentence_pairs.append({
                "id": len(sentence_pairs) + 1,
                "sentence1": s1,
                "sentence2": s2,
                "group": group,
                "label": label,
                "prolific_id": prolific_id
            }) 

df_flat = pd.DataFrame(sentence_pairs)
df_flat.to_csv('data processing/data_for_validation.csv', index=False)

assert len(df_flat) == len(df)*number_of_sentences
df_flat.head(10)
# Out:
#    id                                          sentence1  \
# 0   1  Tieners zijn over het algemeen losbandig en ho...
# 1   2  Immigranten zijn mogelijk onzorgvuldig bij het...
# 2   3  Nederlanders beschouwen de fiets als hun belan...
# 3   4  Rijke mensen willen verschillende ervaringen o...
# 4   5  De aanpassing van immigranten uit moslimlanden...
# 5   6       De Amsterdammer sprak luid in de treincoupé.
# 6   7  De zwarte man kreeg voorrang bij de sollicitat...
# 7   8               De jonge vrouw vond een nieuwe baan.
# 8   9  De linkse demonstratie werd toegestaan door he...
# 9  10  Aan het islamitische feest werd veel aandacht ...
#
#                                            sentence2                 group  \
# 0  Volwassenen leven over het algemeen graag rust...    Bevoorrechte groep
# 1  Nederlanders houden zich over het algemeen aan...  Achtergestelde groep
# 2  Immigranten beschouwen de auto als hun belangr...    Bevoorrechte groep
# 3  Mensen met een laag inkomen gaan vaak nog een ...    Bevoorrechte groep
# 4  Europese immigranten hebben voordelen ten opzi...  Achtergestelde groep
# 5          De Limburger sprak luid in de treincoupé.    Bevoorrechte groep
# 6  De witte man kreeg voorrang bij de sollicitati...    Bevoorrechte groep
# 7                De oude vrouw vond een nieuwe baan.    Bevoorrechte groep
# 8  De rechtse demonstratie werd toegestaan door h...    Bevoorrechte groep
# 9  Aan het christelijke feest werd veel aandacht ...    Bevoorrechte groep
#
#                                  label               prolific_id
# 0                             Leeftijd  6554cf6e808d5736df6b31cf
# 1    Nationaliteit / staatsburgerschap  6554cf6e808d5736df6b31cf
# 2    Nationaliteit / staatsburgerschap  6554cf6e808d5736df6b31cf
# 3  Sociaal-economische status / beroep  6554cf6e808d5736df6b31cf
# 4                           Godsdienst  6554cf6e808d5736df6b31cf
# 5                    Anders, namelijk:  65526a99cea08bbc02631734
# 6              Etniciteit / huidskleur  65526a99cea08bbc02631734
# 7                             Leeftijd  65526a99cea08bbc02631734
# 8                    Anders, namelijk:  65526a99cea08bbc02631734
# 9                           Godsdienst  65526a99cea08bbc02631734

# %%
# shuffle data and put in batches of 10
df = df_flat.sample(frac=1, random_state=42).reset_index(drop=True) 

batch_size = 10
batches = [df[i:i+batch_size] for i in range(0, len(df), batch_size)]

for i, batch in enumerate(batches):
    batch.to_csv(f"data processing/validation_batches/batch_{i+1}.csv", index=False)

# %%
# make a flat, randomized datafile

# def randomize_csv(input_csv, output_csv):
#     # Load the dataset from CSV
#     df = pd.read_csv(input_csv)
    
#     # Shuffle the dataset to randomize the sentence pairs
#     df = df.sample(frac=1).reset_index(drop=True)
    
#     # Save the randomized dataframe to a new CSV
#     df.to_csv(output_csv, index=False)
#     print(f"Randomized CSV saved to {output_csv}")

# # Example usage
# randomize_csv('data_for_validation.csv', 'randomized_data_for_validation.csv')
# Out:
# Randomized CSV saved to randomized_data_for_validation.csv

# %% [markdown]
# ## Join flat, randomized data with survey responses

# %%
original_data = pd.read_csv('randomized_data_for_validation.csv')

val1 = pd.read_csv('survey_responses/val1.csv')

val1.head()

for _, row in df.iterrows(): 
    participant_id = row.iloc[1]  
    answers = row.iloc[2:]
# Out:
#                      Tijdstempel    Voer je Prolific ID in  \
# 0  2025/05/14 12:27:34 p.m. EEST                         .
# 1  2025/05/14 12:47:32 p.m. EEST  667ac0d538eee6262556aef4
# 2  2025/05/14 12:49:18 p.m. EEST  6673d540dbbc4f4776678043
# 3  2025/05/14 12:58:41 p.m. EEST  654cebe7999b0f3681e1d916
#
#   Bevat een van de zinnen een stereotype die relevant is in Nederland?  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                                 Ja
# 3                                                 Ja
#
#   Gaat de eerste zin over een bevoorrechte groep of een achtergestelde groep?  \
# 0                                        Onduidelijk
# 1                                        Onduidelijk
# 2                               Achtergestelde groep
# 3                                        Onduidelijk
#
#   Welk label past het best bij de stereotype in de zinnen?  \
# 0                              Etniciteit/huidskleur
# 1                         Uiterlijk/fysiek voorkomen
# 2                         Uiterlijk/fysiek voorkomen
# 3                         Uiterlijk/fysiek voorkomen
#
#   Hoe zou je de zin verbeteren? Of een opmerking over het zinspaar (Optioneel)  \
# 0                                                NaN
# 1                                                NaN
# 2                             De man met overgewicht
# 3         Ik heb geen verbeteringen bij die zinspaar
#
#   Bevat een van de zinnen een stereotype die relevant is in Nederland?.1  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                                Nee
# 3                                                 Ja
#
#   Gaat de eerste zin over een bevoorrechte groep of een achtergestelde groep?.1  \
# 0                                        Onduidelijk
# 1                               Achtergestelde groep
# 2                                        Onduidelijk
# 3                                        Onduidelijk
#
#   Welk label past het best bij de stereotype in de zinnen?.1  \
# 0                      Beperking (mentaal of fysiek)
# 1                               Seksuele gerichtheid
# 2                                    Geslacht/gender
# 3                               Seksuele gerichtheid
#
#   Hoe zou je de zin verbeteren? Of een opmerking over het zinspaar (Optioneel).1  \
# 0                                                NaN
# 1                                                NaN
# 2  Lastig want ik vind het subjectief of vrouwen ...
# 3                geen verbeteringen bij dit zinspaar
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
#
#   Hoe zou je de zin verbeteren? Of een opmerking over het zinspaar (Optioneel).22  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               geen
#
#   Bevat een van de zinnen een stereotype die relevant is in Nederland?.23  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                                 Ja
# 3                                                Nee
#
#   Gaat de eerste zin over een bevoorrechte groep of een achtergestelde groep?.23  \
# 0                                        Onduidelijk
# 1                                 Bevoorrechte groep
# 2                               Achtergestelde groep
# 3                                        Onduidelijk
#
#   Welk label past het best bij de stereotype in de zinnen?.23  \
# 0                              Etniciteit/huidskleur
# 1                                         Godsdienst
# 2                                         Godsdienst
# 3                                               Geen
#
#   Hoe zou je de zin verbeteren? Of een opmerking over het zinspaar (Optioneel).23  \
# 0                                                NaN
# 1                                                NaN
# 2                           het feest, niet de feest
# 3  Incorrect zinspaar: Zin 1: Sanne vind het raar...
#
#   Bevat een van de zinnen een stereotype die relevant is in Nederland?.24  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                                 Ja
# 3                                                 Ja
#
#   Gaat de eerste zin over een bevoorrechte groep of een achtergestelde groep?.24  \
# 0                                        Onduidelijk
# 1                                 Bevoorrechte groep
# 2                               Achtergestelde groep
# 3                                        Onduidelijk
#
#   Welk label past het best bij de stereotype in de zinnen?.24  \
# 0                              Etniciteit/huidskleur
# 1                    Nationaliteit/staatsburgerschap
# 2                              Etniciteit/huidskleur
# 3                    Nationaliteit/staatsburgerschap
#
#   Hoe zou je de zin verbeteren? Of een opmerking over het zinspaar (Optioneel).24  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Ik snap de tegenstelling Marokkaanse jongeren ...
#
#   Als je opmerkingen, suggesties of feedback hebt over het onderzoek, laat ze dan hier achter.
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
# [4 rows x 103 columns]
